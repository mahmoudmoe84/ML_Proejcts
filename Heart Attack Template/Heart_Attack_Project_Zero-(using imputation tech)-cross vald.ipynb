# %% [markdown]
# <h1 align="center">Heart Attack - EDA</h1>

# %% [markdown]
# 1. [Introduction](#1)
#     - 1.1 [Data Dictionary](#2)
#     - 1.2 [Task](#3)
#     - 1.3 [Understanding Data](#21)
# 2. [Preparation](#4)
#     - 2.1 [Packages](#5)
#     - 2.2 [Data](#6)
#     - 2.3 [Understanding Data](#7)
# 3. [Exploratory Data Analysis](#8)
#     - 3.1 [Univariate Analysis](#9)
#     - 3.2 [Bivariate Analysis](#10)
# 4. [Data Preprocessing](#11)
#     - 4.1 [Conclusions from the EDA](#12)
#     - 4.2 [Packages](#13)
#     - 4.3 [Making features model ready](#14)
# 5. [Modeling](#15)
#     - 5.1 [Linear Classifiers](#16)
#     - 5.2 [Tree Models](#17)

# %% [markdown]
# ### 1. Introduction <a id=1></a>

# %% [markdown]
# #### 1.1 Data Dictionary <a id=2></a>
# `age` - Age of the patient
#
# `sex` - Sex of the patient
#
# `cp` - Chest pain type ~ 0 = Typical Angina, 1 = Atypical Angina, 2 = Non-anginal Pain, 3 = Asymptomatic
#
# `trtbps` - Resting blood pressure (in mm Hg)
#
# `chol` - Cholestoral in mg/dl fetched via BMI sensor
#
# `fbs` - (fasting blood sugar > 120 mg/dl) ~ 1 = True, 0 = False
#
# `restecg` - Resting electrocardiographic results ~ 0 = Normal, 1 = ST-T wave normality, 2 = Left ventricular hypertrophy
#
# `thalachh`  - Maximum heart rate achieved
#
# `oldpeak` - Previous peak
#
# `slp` - Slope
#
# `caa` - Number of major vessels
#
# `thall` - Thalium Stress Test result ~ (0,3)
#
# `exng` - Exercise induced angina ~ 1 = Yes, 0 = No
#
# `output` - Target variable
#
# **Additional Variables Explaination from Kaggle**
#
# **age** - age in years
#
# **sex** - sex (1 = male; 0 = female)
#
# **cp** - chest pain type (1 = typical angina; 2 = atypical angina; 3 = non-anginal pain; 0 = asymptomatic)
#
# **trestbps** - resting blood pressure (in mm Hg on admission to the hospital)
#
# **chol** - serum cholestoral in mg/dl
#
# **fbs** - fasting blood sugar > 120 mg/dl (1 = true; 0 = false)
#
# **restecg** - resting electrocardiographic results (1 = normal; 2 = having ST-T wave abnormality; 0 = hypertrophy)
#
# **thalach** - maximum heart rate achieved
#
# **exang** - exercise induced angina (1 = yes; 0 = no)
#
# **oldpeak** - ST depression induced by exercise relative to rest
#
# **slope** - the slope of the peak exercise ST segment (2 = upsloping; 1 = flat; 0 = downsloping)
#
# **ca** - number of major vessels (0-3) colored by flourosopy
#
# **thal** - 2 = normal; 1 = fixed defect; 3 = reversable defect
#
# **num** - the predicted attribute - diagnosis of heart disease (angiographic disease status) (Value 0 = < diameter narrowing; Value 1 = > 50% diameter narrowing)
#
#     Variable definition can be found in the discussion section

# %% [markdown]
# #### 1.2 Task <a id=3></a>
# To perform EDA and predict if a person is prone to a heart attack or not.

# %% [markdown]
# #### 1.3 Understanding Data <a id=21></a>
# * What is Heart Attack?
#
#
#
#
#
# * How does it Happen?
#
#
#
#
# * What are the most contributing Factors for heart attack to happen ?
#
#
#
# * symptoms of heart attack for male and female?

# %% [markdown]
# ### 2. Preparation <a id=4></a>

# %% [markdown]
# #### 2.1 Packages <a id=5></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msn
# %matplotlib inline
sns.set() 
import requests

# %% [markdown]
# #### 2.2 Data <a id=6></a>

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\user\\ML-projects\\ML_Proejcts\\Heart Attack Template'

# %%
def get_link(url):
    file_name = url.split('/')[-1]
    response = requests.get(url,allow_redirects=True) 
    if not os.path.isfile(file_name):
        with open(file_name, mode = 'wb') as file:
            file.write(response.content)

# %%
#dowenload datasets from Ucsi repo 
cleveland = get_link('https://archive.ics.uci.edu/ml/machine-learning-databases/heart-disease/processed.cleveland.data')
hungarian = get_link('https://archive.ics.uci.edu/ml/machine-learning-databases/heart-disease/processed.hungarian.data')
switzerland = get_link('https://archive.ics.uci.edu/ml/machine-learning-databases/heart-disease/processed.switzerland.data')
va = get_link('https://archive.ics.uci.edu/ml/machine-learning-databases/heart-disease/processed.va.data')

# %%
os.getcwd()
# Out:
# 'C:\\Users\\user\\ML-projects\\ML_Proejcts\\Heart Attack Template'

# %%
df_clv = pd.read_csv("processed.cleveland.data" ,header = None)
df_hun = pd.read_csv("processed.hungarian.data" ,header = None)
df_sw = pd.read_csv("processed.switzerland.data" ,header = None)
df_va = pd.read_csv("processed.va.data" ,header = None)

# %% [markdown]
# #### creating function to append columns

# %%
def append_columns(df):
    columns = [['age','sex','cp','trestbps','chol','fbs','restecg' ,'thalach',
                'eaxng' ,'oldpeak','slope','ca','thal','output']]
    for col in columns:
        df.columns=col

# %%
#let's append columns 
data_frames= [df_clv ,df_hun ,df_sw,df_va]
for df in data_frames:
    append_columns(df)

# %% [markdown]
# #### define fuction to add location

# %%
def add_location(df , place):
        df['place'] = place

# %%
add_location(df_clv ,'clev')
add_location(df_hun , 'hun')
add_location(df_sw , 'sw')
add_location(df_va , 'va')

# %% [markdown]
# ### Concating all dataframes together

# %%
df = pd.concat([df_clv, df_hun ,df_sw ,df_va], ignore_index=True)
pd.set_option('display.max_rows', None)
df
# Out:
#       age  sex   cp trestbps chol fbs restecg thalach eaxng oldpeak slope  \
# 0    63.0  1.0  1.0      145  233   1       2     150     0     2.3     3
# 1    67.0  1.0  4.0      160  286   0       2     108     1     1.5     2
# 2    67.0  1.0  4.0      120  229   0       2     129     1     2.6     2
# 3    37.0  1.0  3.0      130  250   0       0     187     0     3.5     3
# 4    41.0  0.0  2.0      130  204   0       2     172     0     1.4     1
# 5    56.0  1.0  2.0      120  236   0       0     178     0     0.8     1
# 6    62.0  0.0  4.0      140  268   0       2     160     0     3.6     3
# 7    57.0  0.0  4.0      120  354   0       0     163     1     0.6     1
# 8    63.0  1.0  4.0      130  254   0       2     147     0     1.4     2
# 9    53.0  1.0  4.0      140  203   1       2     155     1     3.1     3
# 10   57.0  1.0  4.0      140  192   0       0     148     0     0.4     2
# 11   56.0  0.0  2.0      140  294   0       2     153     0     1.3     2
# 12   56.0  1.0  3.0      130  256   1       2     142     1     0.6     2
# 13   44.0  1.0  2.0      120  263   0       0     173     0       0     1
# 14   52.0  1.0  3.0      172  199   1       0     162     0     0.5     1
# 15   57.0  1.0  3.0      150  168   0       0     174     0     1.6     1
# 16   48.0  1.0  2.0      110  229   0       0     168     0       1     3
# 486    ?    ?       0   hun
# 487    ?    ?       0   hun
# 488    ?    ?       0   hun
# 489    ?    ?       0   hun
# 490    ?    ?       0   hun
# 491    ?    ?       1   hun
# 492    ?    ?       1   hun
# 493    ?    ?       1   hun
# 494    ?    ?       1   hun
# 495    ?    ?       1   hun
# 496    ?    ?       1   hun
# 497    ?    ?       1   hun
# 498    ?    ?       1   hun
# 499    ?    ?       1   hun
# 500    ?    6       1   hun
# 501    ?    6       1   hun
# 502    ?    ?       1   hun
# 503    ?    ?       1   hun
# 504    ?    ?       1   hun
# 505    ?    7       1   hun
# 506    ?    ?       1   hun
# 507    ?    ?       1   hun
# 508    0    7       1   hun
# 509    ?    ?       1   hun
# 510    ?    ?       1   hun
# 511    ?    ?       1   hun
# 512    ?    ?       1   hun
# 513    ?    ?       1   hun
# 514    ?    ?       1   hun
# 515    ?    7       1   hun
# 516    ?    ?       1   hun
# 517    ?    ?       1   hun
# 518    ?    ?       1   hun
# 519    ?    ?       1   hun
# 520    ?    ?       1   hun
# 521    ?    ?       1   hun
# 522    ?    ?       1   hun
# 523    ?    6       1   hun
# 524    ?    ?       1   hun
# 525    ?    ?       1   hun
# 526    ?    ?       1   hun
# 527    ?    ?       1   hun
# 528    ?    ?       1   hun
# 529    ?    ?       1   hun
# 530    ?    6       1   hun
# 531    ?    6       1   hun
# 532    ?    ?       1   hun
# 533    ?    ?       1   hun
# 534    ?    ?       1   hun
# 535    ?    ?       1   hun
# 536    ?    ?       1   hun
# 537    ?    ?       1   hun
# 538    ?    ?       1   hun
# 539    ?    ?       1   hun
# 540    ?    7       1   hun
# 541    ?    ?       1   hun
# 542    ?    ?       1   hun
# 543    ?    ?       1   hun
# 544    ?    7       1   hun
# 545    ?    ?       1   hun
# 546    ?    ?       1   hun
# 547    ?    ?       1   hun
# 548    ?    ?       1   hun
# 549    ?    ?       1   hun
# 550    ?    ?       1   hun
# 551    ?    ?       1   hun
# 552    ?    ?       1   hun
# 553    ?    ?       1   hun
# 554    ?    ?       1   hun
# 555    ?    7       1   hun
# 556    ?    ?       1   hun
# 557    ?    ?       1   hun
# 558    ?    ?       1   hun
# 559    ?    ?       1   hun
# 560    ?    ?       1   hun
# 561    ?    ?       1   hun
# 562    ?    ?       1   hun
# 563    ?    ?       1   hun
# 564    ?    ?       1   hun
# 565    ?    ?       1   hun
# 566    ?    ?       1   hun
# 567    ?    ?       1   hun
# 568    ?    ?       1   hun
# 569    ?    ?       1   hun
# 570    ?    ?       1   hun
# 571    ?    ?       1   hun
# 572    ?    ?       1   hun
# 573    ?    ?       1   hun
# 574    ?    ?       1   hun
# 575    ?    ?       1   hun
# 576    ?    ?       1   hun
# 577    ?    ?       1   hun
# 578    ?    ?       1   hun
# 579    ?    ?       1   hun
# 580    ?    ?       1   hun
# 581    ?    ?       1   hun
# 582    ?    ?       1   hun
# 583    ?    ?       1   hun
# 584    ?    ?       1   hun
# 585    ?    6       1   hun
# 586    ?    ?       1   hun
# 587    ?    ?       1   hun
# 588    ?    ?       1   hun
# 917    ?    6       2    va
# 918    ?    ?       0    va
# 919    ?    ?       1    va

# %% [markdown]
# #### 2.3 Understanding Data

# %% [markdown]
# ##### 2.3.1 The shape of the data

# %%
df.shape
# Out:
# (920, 15)

# %% [markdown]
# ##### 2.3.2 Preview random 5 rows of the data

# %%
df.sample(5)
# Out:
#       age  sex   cp trestbps chol fbs restecg thalach eaxng oldpeak slope ca  \
# 720  63.0  1.0  4.0      140  260   0       1     112     1       3     2  ?
# 903  56.0  1.0  4.0      130  203   1       0      98     0     1.5     2  ?
# 471  56.0  1.0  3.0      130    ?   0       0     114     0       0     ?  ?
# 610  42.0  1.0  4.0      145    0   0       0      99     1       0     2  ?
# 799  64.0  0.0  4.0      142  276   0       0     140     1       1     2  ?
#
#     thal  output place
# 720    ?       2    va
# 903    7       1    va
# 471    ?       0   hun
# 610    ?       2    sw
# 799    7       1    va

# %% [markdown]
# ##### 2.3.3 Checking the number of unique values in each column

# %%
for i in df.columns:
    print(pd.DataFrame(df[i].value_counts()))
# Out:
#       age
# 54.0   51
# 58.0   43
# 55.0   41
# 56.0   38
# 57.0   38
# 52.0   36
# 51.0   35
# 62.0   35
# 59.0   35
# 53.0   33
# 60.0   32
# 61.0   31
# 48.0   31
# 63.0   30
# 50.0   25
# 46.0   24
# 41.0   24
# 43.0   24
# 49.0   22
# 64.0   22
# 65.0   21
# 47.0   19
# 44.0   19
# 42.0   18
# 45.0   18
# 38.0   16
# 39.0   15
# 67.0   15
# 40.0   13
# 66.0   13
# 69.0   13
# 37.0   11
# 35.0   11
# 68.0   10
# 74.0    7
# 70.0    7
# 34.0    7
# 36.0    6
# 71.0    5
# 32.0    5
# 72.0    4
# 29.0    3
# 75.0    3
# 31.0    2
# 33.0    2
# 76.0    2
# 77.0    2
# 30.0    1
# 28.0    1
# 73.0    1
#      sex
# 1.0  726
# 0.0  194
#       cp
# 4.0  496
# 3.0  204
# 2.0  174
# 1.0   46
#        trestbps
# 120          94
# 130          79
# 140          70
# ?            59
# 110          40
# 160          39
# 150          39
# 120.0        37
# 130.0        36
# 140.0        32
# 110.0        19
# 125          18
# 150.0        17
# 115          16
# 135          12
# 138.0        12
# 128.0        12
# 145          11
# 125.0        11
# 160.0        11
# 100          11
# 170          10
# 112.0         9
# 180           9
# 122           8
# 132.0         8
# 118.0         7
# 155           7
# 105           6
# 124           6
# 124.0         6
# 142           6
# 108.0         6
# 95            6
# 135.0         6
# 145.0         5
# 112           5
# 152.0         5
# 134.0         5
# 128           5
# 136           5
# 122.0         4
# 100.0         4
# 132           4
# 134           4
# 170.0         4
# 144           4
# 126           4
# 180.0         3
# 158           3
# 142.0         3
# 105.0         3
# 200           3
# 138           3
# 126.0         3
# 118           3
# 115.0         3
# 136.0         3
# 102.0         2
# 94.0          2
# 152           2
# 190           2
# 154           2
# 106           2
# 104           2
# 178.0         2
# 144.0         2
# 116           2
# 148.0         2
# 146.0         2
# 114.0         1
# 117.0         1
# 96            1
# 185           1
# 98            1
# 102           1
# 0             1
# 127           1
# -.5         1
# -1.1        1
# .4          1
# 2.9         1
# 2.1         1
# -.9         1
#      slope
# ?      309
# 2      205
# 1.0    142
# 2.0    140
# 1       61
# 3       42
# 3.0     21
#       ca
# ?    611
# 0.0  176
# 1.0   65
# 2.0   38
# 3.0   20
# 0      5
# 2      3
# 1      2
#      thal
# ?     486
# 3.0   166
# 7.0   117
# 7      75
# 3      30
# 6      28
# 6.0    18
#    output
# 0     411
# 1     265
# 2     109
# 3     107
# 4      28
#       place
# clev    303
# hun     294
# va      200
# sw      123

# %%
for i in df.columns:
    print(f"The unique value in the {i} column = ", df[i].unique())
    print("----------------------------------------------------------------------------")
# Out:
# The unique value in the age column =  [63. 67. 37. 41. 56. 62. 57. 53. 44. 52. 48. 54. 49. 64. 58. 60. 50. 66.
#  43. 40. 69. 59. 42. 55. 61. 65. 71. 51. 46. 45. 39. 68. 47. 34. 35. 29.
#  70. 77. 38. 74. 76. 28. 30. 31. 32. 33. 36. 72. 73. 75.]
# ----------------------------------------------------------------------------
# The unique value in the sex column =  [1. 0.]
# ----------------------------------------------------------------------------
# The unique value in the cp column =  [1. 4. 3. 2.]
# ----------------------------------------------------------------------------
# The unique value in the trestbps column =  [145.0 160.0 120.0 130.0 140.0 172.0 150.0 110.0 132.0 117.0 135.0 112.0
#  105.0 124.0 125.0 142.0 128.0 170.0 155.0 104.0 180.0 138.0 108.0 134.0
#  122.0 115.0 118.0 100.0 200.0 94.0 165.0 102.0 152.0 101.0 126.0 174.0
#  148.0 178.0 158.0 192.0 129.0 144.0 123.0 136.0 146.0 106.0 156.0 154.0
#  114.0 164.0 '130' '120' '140' '170' '100' '105' '110' '125' '150' '98'
#  '112' '145' '190' '160' '115' '142' '180' '132' '135' '?' '108' '124'
#  '113' '122' '92' '118' '106' '200' '138' '136' '128' '155' '95' '165'
#  '80' '185' '126' '152' '116' '0' '144' '154' '104' '134' '178' '146'
#  '158' '102' '96' '172' '156' '114' '127']
# ----------------------------------------------------------------------------
# The unique value in the chol column =  [233.0 286.0 229.0 250.0 204.0 236.0 268.0 354.0 254.0 203.0 192.0 294.0
#  256.0 263.0 199.0 168.0 239.0 275.0 266.0 211.0 283.0 284.0 224.0 206.0
#  219.0 340.0 226.0 247.0 167.0 230.0 335.0 234.0 177.0 276.0 353.0 243.0
#  225.0 302.0 212.0 330.0 175.0 417.0 197.0 198.0 290.0 253.0 172.0 273.0
#  213.0 305.0 216.0 304.0 188.0 282.0 185.0 232.0 326.0 231.0 269.0 267.0
#  248.0 360.0 258.0 308.0 245.0 270.0 208.0 264.0 321.0 274.0 325.0 235.0
#  257.0 164.0 141.0 252.0 255.0 201.0 222.0 260.0 182.0 303.0 265.0 309.0
#  307.0 249.0 186.0 341.0 183.0 407.0 217.0 288.0 220.0 209.0 227.0 261.0
#  174.0 281.0 221.0 205.0 240.0 289.0 318.0 298.0 564.0 246.0 322.0 299.0
#  300.0 293.0 277.0 214.0 207.0 223.0 160.0 394.0 184.0 315.0 409.0 244.0
#  195.0 196.0 126.0 313.0 259.0 200.0 262.0 215.0 228.0 193.0 271.0 210.0
#  327.0 149.0 295.0 306.0 178.0 237.0 218.0 242.0 319.0 166.0 180.0 311.0
#  278.0 342.0 169.0 187.0 157.0 176.0 241.0 131.0 '132' '243' '?' '237'
#  '219' '198' '225' '254' '298' '161' '214' '220' '160' '167' '308' '264'
#  '166' '340' '209' '260' '211' '173' '283' '194' '223' '315' '275' '297'
#  '292' '182' '200' '204' '241' '339' '147' '273' '307' '289' '215' '281'
#  '250' '184' '245' '291' '295' '269' '196' '268' '228' '358' '201' '249'
#  '266' '186' '207' '218' '412' '224' '238' '230' '163' '240' '280' '257'
#  '263' '276' '284' '195' '227' '253' '187' '202' '328' '168' '216' '129'
#  '190' '188' '179' '210' '272' '180' '100' '259' '468' '274' '320' '221'
#  '309' '312' '171' '208' '246' '305' '217' '365' '344' '394' '256' '326'
#  '277' '270' '229' '85' '347' '251' '222' '287' '318' '213' '294' '193'
#  '271' '156' '267' '282' '117' '466' '247' '226' '265' '206' '288' '303'
#  '338' '248' '306' '529' '392' '231' '329' '355' '233' '242' '603' '255'
#  '172' '175' '290' '341' '234' '342' '404' '518' '285' '279' '388' '164'
#  '336' '491' '205' '212' '331' '393' 0 '0' '236' '177' '203' '153' '316'
#  '311' '252' '458' '384' '258' '235' '349' '142' '197' '192' '261' '181'
#  '310' '232' '170' '369' '244' '165' '337' '300' '333' '139' '385']
# ----------------------------------------------------------------------------
# The unique value in the fbs column =  [1.0 0.0 '0' '?' '1']
# ----------------------------------------------------------------------------
# The unique value in the restecg column =  [2.0 0.0 1.0 '2' '0' '1' '?']
# ----------------------------------------------------------------------------
# The unique value in the thalach column =  [150.0 108.0 129.0 187.0 172.0 178.0 160.0 163.0 147.0 155.0 148.0 153.0
#  142.0 173.0 162.0 174.0 168.0 139.0 171.0 144.0 132.0 158.0 114.0 151.0
#  161.0 179.0 120.0 112.0 137.0 157.0 169.0 165.0 123.0 128.0 152.0 140.0
#  188.0 109.0 125.0 131.0 170.0 113.0 99.0 177.0 141.0 180.0 111.0 143.0
#  182.0 156.0 115.0 149.0 145.0 146.0 175.0 186.0 185.0 159.0 130.0 190.0
#  136.0 97.0 127.0 154.0 133.0 126.0 202.0 103.0 166.0 164.0 184.0 124.0
#  122.0 96.0 138.0 88.0 105.0 194.0 195.0 106.0 167.0 95.0 192.0 117.0
#  121.0 116.0 71.0 118.0 181.0 134.0 90.0 '185' '160' '170' '150' '165'
#  '184' '155' '190' '168' '180' '178' '172' '130' '142' '98' '158' '129'
#  '146' '145' '120' '106' '132' '140' '138' '167' '188' '144' '137' '136'
#  '152' '175' '176' '118' '154' '115' '135' '122' '110' '90' '116' '174'
#  '125' '?' '148' '100' '164' '139' '127' '162' '112' '134' '114' '128'
#  '126' '124' '153' '166' '103' '156' '87' '102' '92' '99' '121' '91' '108'
#  '96' '82' '105' '143' '119' '94' '179' '133' '113' '149' '104' '163' '60'
#  '95' '141' '83' '97' '131' '182' '63' '70' '77' '117' '123' '72' '78'
#  '109' '86' '93' '67' '157' '84' '111' '80' '107' '161' '69' '88' '73'
#  '159' '151']
# ----------------------------------------------------------------------------
# The unique value in the eaxng column =  [0.0 1.0 '0' '1' '?']
# ----------------------------------------------------------------------------
# The unique value in the oldpeak column =  [2.3 1.5 2.6 3.5 1.4 0.8 3.6 0.6 3.1 0.4 1.3 0.0 0.5 1.6 1.0 1.2 0.2 1.8
#  3.2 2.4 2.0 2.5 2.2 2.8 3.0 3.4 6.2 4.0 5.6 2.9 0.1 2.1 1.9 4.2 0.9 1.1
#  3.8 0.7 0.3 4.4 5.0 '.7' '.2' '?' '1' '2.8' '0' '-1.1' '1.6' '-1.5' '1.5'
#  '2' '.5' '-.1' '-2.6' '2.1' '-.7' '2.2' '3' '.1' '.3' '-2' '-1' '1.8'
#  '1.4' '2.6' '.9' '2.4' '1.1' '.4' '2.5' '1.7' '-.8' '-.5' '-.9' '3.7'
#  '1.3' '-0.5' '0.5' '4' '3.5' '0.8']
# ----------------------------------------------------------------------------
# The unique value in the slope column =  [3.0 2.0 1.0 '?' '2' '1' '3']
# ----------------------------------------------------------------------------
# The unique value in the ca column =  ['0.0' '3.0' '2.0' '1.0' '?' '0' '1' '2']
# ----------------------------------------------------------------------------
# The unique value in the thal column =  ['6.0' '3.0' '7.0' '?' '6' '3' '7']
# ----------------------------------------------------------------------------
# The unique value in the output column =  [0 2 1 3 4]
# ----------------------------------------------------------------------------
# The unique value in the place column =  ['clev' 'hun' 'sw' 'va']
# ----------------------------------------------------------------------------

# %% [markdown]
# ##### 2.3.4 Separating the columns in categorical and continuous

# %% [markdown]
# ##### 2.3.5 Summary statistics

# %%
df.describe().T
# Out:
#         count       mean       std   min   25%   50%   75%   max
# age     920.0  53.510870  9.424685  28.0  47.0  54.0  60.0  77.0
# sex     920.0   0.789130  0.408148   0.0   1.0   1.0   1.0   1.0
# cp      920.0   3.250000  0.930969   1.0   3.0   4.0   4.0   4.0
# output  920.0   0.995652  1.142693   0.0   0.0   1.0   2.0   4.0

# %%
df.head(3)
# Out:
#     age  sex   cp trestbps chol fbs restecg thalach eaxng oldpeak slope   ca  \
# 0  63.0  1.0  1.0      145  233   1       2     150     0     2.3     3  0.0
# 1  67.0  1.0  4.0      160  286   0       2     108     1     1.5     2  3.0
# 2  67.0  1.0  4.0      120  229   0       2     129     1     2.6     2  2.0
#
#   thal  output place
# 0  6.0       0  clev
# 1  3.0       2  clev
# 2  7.0       1  clev

# %%
df.describe(include='all').T
# Out:
#          count unique   top freq      mean       std  min  25%  50%  75%  max
# age        920    NaN   NaN  NaN   53.5109   9.42469   28   47   54   60   77
# sex        920    NaN   NaN  NaN   0.78913  0.408148    0    1    1    1    1
# cp         920    NaN   NaN  NaN      3.25  0.930969    1    3    4    4    4
# trestbps   920    103   120   94       NaN       NaN  NaN  NaN  NaN  NaN  NaN
# chol       920    336     0  123       NaN       NaN  NaN  NaN  NaN  NaN  NaN
# fbs        920      5     0  434       NaN       NaN  NaN  NaN  NaN  NaN  NaN
# restecg    920      7     0  320       NaN       NaN  NaN  NaN  NaN  NaN  NaN
# thalach    920    198     ?   55       NaN       NaN  NaN  NaN  NaN  NaN  NaN
# eaxng      920      5     0  324       NaN       NaN  NaN  NaN  NaN  NaN  NaN
# oldpeak    920     82     0  288       NaN       NaN  NaN  NaN  NaN  NaN  NaN
# slope      920      7     ?  309       NaN       NaN  NaN  NaN  NaN  NaN  NaN
# ca         920      8     ?  611       NaN       NaN  NaN  NaN  NaN  NaN  NaN
# thal       920      7     ?  486       NaN       NaN  NaN  NaN  NaN  NaN  NaN
# output     920    NaN   NaN  NaN  0.995652   1.14269    0    0    1    2    4
# place      920      4  clev  303       NaN       NaN  NaN  NaN  NaN  NaN  NaN

# %% [markdown]
# ##### 2.3.6 Missing values

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# eaxng       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# output      0
# place       0
# dtype: int64

# %% [markdown]
# ##### 2.3.6 dupicated  values

# %%
df.duplicated().any()
# Out:
# True

# %% [markdown]
# ## Handlling errors and  missing values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 920 entries, 0 to 919
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       920 non-null    float64
#  1   sex       920 non-null    float64
#  2   cp        920 non-null    float64
#  3   trestbps  920 non-null    object
#  4   chol      920 non-null    object
#  5   fbs       920 non-null    object
#  6   restecg   920 non-null    object
#  7   thalach   920 non-null    object
#  8   eaxng     920 non-null    object
#  9   oldpeak   920 non-null    object
#  10  slope     920 non-null    object
#  11  ca        920 non-null    object
#  12  thal      920 non-null    object
#  13  output    920 non-null    int64
#  14  place     920 non-null    object
# dtypes: float64(3), int64(1), object(11)
# memory usage: 107.9+ KB

# %%
for i in df.columns:
    print(pd.DataFrame(df[i].value_counts()))
# Out:
#       age
# 54.0   51
# 58.0   43
# 55.0   41
# 56.0   38
# 57.0   38
# 52.0   36
# 51.0   35
# 62.0   35
# 59.0   35
# 53.0   33
# 60.0   32
# 61.0   31
# 48.0   31
# 63.0   30
# 50.0   25
# 46.0   24
# 41.0   24
# 43.0   24
# 49.0   22
# 64.0   22
# 65.0   21
# 47.0   19
# 44.0   19
# 42.0   18
# 45.0   18
# 38.0   16
# 39.0   15
# 67.0   15
# 40.0   13
# 66.0   13
# 69.0   13
# 37.0   11
# 35.0   11
# 68.0   10
# 74.0    7
# 70.0    7
# 34.0    7
# 36.0    6
# 71.0    5
# 32.0    5
# 72.0    4
# 29.0    3
# 75.0    3
# 31.0    2
# 33.0    2
# 76.0    2
# 77.0    2
# 30.0    1
# 28.0    1
# 73.0    1
#      sex
# 1.0  726
# 0.0  194
#       cp
# 4.0  496
# 3.0  204
# 2.0  174
# 1.0   46
#        trestbps
# 120          94
# 130          79
# 140          70
# ?            59
# 110          40
# 160          39
# 150          39
# 120.0        37
# 130.0        36
# 140.0        32
# 110.0        19
# 125          18
# 150.0        17
# 115          16
# 135          12
# 138.0        12
# 128.0        12
# 145          11
# 125.0        11
# 160.0        11
# 100          11
# 170          10
# 112.0         9
# 180           9
# 122           8
# 132.0         8
# 118.0         7
# 155           7
# 105           6
# 124           6
# 124.0         6
# 142           6
# 108.0         6
# 95            6
# 135.0         6
# 145.0         5
# 112           5
# 152.0         5
# 134.0         5
# 128           5
# 136           5
# 122.0         4
# 100.0         4
# 132           4
# 134           4
# 170.0         4
# 144           4
# 126           4
# 180.0         3
# 158           3
# 142.0         3
# 105.0         3
# 200           3
# 138           3
# 126.0         3
# 118           3
# 115.0         3
# 136.0         3
# 102.0         2
# 94.0          2
# 152           2
# 190           2
# 154           2
# 106           2
# 104           2
# 178.0         2
# 144.0         2
# 116           2
# 148.0         2
# 146.0         2
# 114.0         1
# 117.0         1
# 96            1
# 185           1
# 98            1
# 102           1
# 0             1
# 127           1
# 172           1
# 146           1
# 101.0         1
# 108           1
# 165           1
# 178           1
# 200.0         1
#      slope
# ?      309
# 2      205
# 1.0    142
# 2.0    140
# 1       61
# 3       42
# 3.0     21
#       ca
# ?    611
# 0.0  176
# 1.0   65
# 2.0   38
# 3.0   20
# 0      5
# 2      3
# 1      2
#      thal
# ?     486
# 3.0   166
# 7.0   117
# 7      75
# 3      30
# 6      28
# 6.0    18
#    output
# 0     411
# 1     265
# 2     109
# 3     107
# 4      28
#       place
# clev    303
# hun     294
# va      200
# sw      123

# %%
df = df.replace('?', np.NaN)

# %%
df.isnull().sum()
# Out:
# age           0
# sex           0
# cp            0
# trestbps     59
# chol         30
# fbs          90
# restecg       2
# thalach      55
# eaxng        55
# oldpeak      62
# slope       309
# ca          611
# thal        486
# output        0
# place         0
# dtype: int64

# %%
df['output'].value_counts()
# Out:
# 0    411
# 1    265
# 2    109
# 3    107
# 4     28
# Name: output, dtype: int64

# %% [markdown]
# ### handlling error in target column

# %%
df['output'] = df['output'].apply(lambda x:1 if x >=1 else 0)

# %%
df['output'].value_counts()
# Out:
# 1    509
# 0    411
# Name: output, dtype: int64

# %% [markdown]
# ### imputing missing values using machine learning

# %%
df.drop('place',inplace=True ,axis=1)

# %%
df.sample()
# Out:
#       age  sex   cp trestbps chol fbs restecg thalach eaxng oldpeak slope  \
# 139  51.0  1.0  3.0      125  245   1       2     166     0     2.4     2
#
#       ca thal  output
# 139  0.0  3.0       0

# %%
x=df.values

# %%
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
it_imputer =  IterativeImputer(random_state=42 ,)   
x = it_imputer.fit_transform(x)

# %%
np.isnan(x).any()
# Out:
# False

# %%
df =pd.DataFrame(data=x, columns=df.columns)

# %%
df.head()
# Out:
#     age  sex   cp  trestbps   chol  fbs  restecg  thalach  eaxng  oldpeak  \
# 0  63.0  1.0  1.0     145.0  233.0  1.0      2.0    150.0    0.0      2.3
# 1  67.0  1.0  4.0     160.0  286.0  0.0      2.0    108.0    1.0      1.5
# 2  67.0  1.0  4.0     120.0  229.0  0.0      2.0    129.0    1.0      2.6
# 3  37.0  1.0  3.0     130.0  250.0  0.0      0.0    187.0    0.0      3.5
# 4  41.0  0.0  2.0     130.0  204.0  0.0      2.0    172.0    0.0      1.4
#
#    slope   ca  thal  output
# 0    3.0  0.0   6.0     0.0
# 1    2.0  3.0   3.0     1.0
# 2    2.0  2.0   7.0     1.0
# 3    3.0  0.0   3.0     0.0
# 4    1.0  0.0   3.0     0.0

# %%
df.shape
# Out:
# (920, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 920 entries, 0 to 919
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       920 non-null    float64
#  1   sex       920 non-null    float64
#  2   cp        920 non-null    float64
#  3   trestbps  920 non-null    float64
#  4   chol      920 non-null    float64
#  5   fbs       920 non-null    float64
#  6   restecg   920 non-null    float64
#  7   thalach   920 non-null    float64
#  8   eaxng     920 non-null    float64
#  9   oldpeak   920 non-null    float64
#  10  slope     920 non-null    float64
#  11  ca        920 non-null    float64
#  12  thal      920 non-null    float64
#  13  output    920 non-null    float64
# dtypes: float64(14)
# memory usage: 100.8 KB

# %%
cat_feature = df[['sex','cp','fbs','restecg','eaxng']]
cat_feature.sample()
# Out:
#      sex   cp  fbs  restecg  eaxng
# 228  1.0  4.0  0.0      2.0    1.0

# %%
cont_fetaure =df[['age','trestbps','chol','thalach','oldpeak']]
cont_fetaure.sample()
# Out:
#       age  trestbps        chol  thalach  oldpeak
# 368  43.0     150.0  263.841431    175.0      0.0

# %% [markdown]
# ### 3. Exploratory Data Analysis <a id=8></a>

# %% [markdown]
# #### 3.1 Univariate Analysis <a id=9></a>

# %% [markdown]
# ##### 3.1.1 Count plot of categorical features

# %%
for i in cat_feature:
    sns.countplot(df[i])
    plt.show();

# %% [markdown]
# ##### 3.1.2 Boxen plot of continuous features

# %%
plt.figure(figsize=(15,10))
cont_fetaure.boxplot();
plt.show()

# %%
for i in cont_fetaure:
    sns.distplot(df[i])
    plt.show()

# %% [markdown]
# ##### 3.1.2 Count plot of target

# %% [markdown]
# #### 3.2 Bivariate Analysis <a id=10></a>

# %% [markdown]
# ##### 3.2.1 Correlation matrix of continuous features

# %%
cont_fetaure.corr()
# Out:
#                age  trestbps      chol   thalach   oldpeak
# age       1.000000  0.254004 -0.091420 -0.373476  0.261706
# trestbps  0.254004  1.000000  0.098388 -0.109750  0.165079
# chol     -0.091420  0.098388  1.000000  0.241283  0.053234
# thalach  -0.373476 -0.109750  0.241283  1.000000 -0.155570
# oldpeak   0.261706  0.165079  0.053234 -0.155570  1.000000

# %% [markdown]
# ##### 3.2.2 Scatterplot heatmap of dataframe

# %%
plt.figure(figsize=(12,6))
sns.heatmap(df.corr(),annot=True , cmap='Blues')

# %% [markdown]
# ##### 3.2.3 Distribution of continuous features according to target variable

# %% [markdown]
# ##### 3.2.4 Some other relations that seemed intuitive

# %% [markdown]
# ##### 3.2.5 Pairplot according to target variable - one plot to rule them all

# %%
sns.pairplot(cont_fetaure, kind="scatter")
plt.show()

# %% [markdown]
# ### 4. Data Preprocessing <a id=11></a>

# %% [markdown]
# #### 4.1 Conclusions from the EDA <a id=12></a>

# %% [markdown]
# #### 4.2 Packages <a id=13></a>

# %%
from sklearn.preprocessing import minmax_scale
from sklearn.preprocessing import normalize

# %% [markdown]
# #### 4.3 Making features model ready <a id=14></a>

# %% [markdown]
# ##### 4.3.1 Scaling and Encoding features

# %%
X = df.iloc[: , :-1].to_numpy()
X
# Out:
# array([[63.        ,  1.        ,  1.        , ...,  3.        ,
#          0.        ,  6.        ],
#        [67.        ,  1.        ,  4.        , ...,  2.        ,
#          3.        ,  3.        ],
#        [67.        ,  1.        ,  4.        , ...,  2.        ,
#          2.        ,  7.        ],
#        ...,
#        [55.        ,  1.        ,  4.        , ...,  1.8553608 ,
#          1.16016058,  6.        ],
#        [58.        ,  1.        ,  4.        , ...,  1.67630475,
#          0.80846   ,  5.20946317],
#        [62.        ,  1.        ,  2.        , ...,  1.92990612,
#          0.93911256,  5.5314508 ]])

# %%
Y = df.iloc[: , -1].to_numpy()

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
scaled_X= sc.fit_transform(X)

# %% [markdown]
# ##### 4.3.2 Train and test split

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(scaled_X,Y ,test_size=.2 , random_state=42)

# %% [markdown]
# ### 5. Modeling <a id=15></a>

# %% [markdown]
# #### 5.1 Linear Classifiers <a id=16></a>

# %% [markdown]
# ##### 5.1.1 Support Vector Machines

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score , confusion_matrix
score = []
kernel = ['linear' , 'rbf' , 'sigmoid','poly']
for k in kernel:
  model = SVC(kernel=k , degree=3, gamma='scale')
  model.fit(X_train,y_train)
  y_pred = model.predict(X_test)
  score.append(accuracy_score(y_pred , y_test))

# %% [markdown]
# ##### 5.1.2 Hyperparameter tuning of SVC

# %%
plt.plot(range(len(kernel)) , score )
plt.xticks(labels=kernel ,ticks=range(len(kernel)));

# %%
score = []
c= [1,10 ,100 ,1000]
for i in c:
  model = SVC(C=i , kernel='rbf', degree=3, gamma='auto')
  model.fit(X_train ,y_train)
  y_pred = model.predict(X_test)
  score.append(accuracy_score(y_pred , y_test))

# %%
plt.plot(score,range(len(c)))
plt.yticks(labels=c ,ticks=range(len(c)));

# %%
model = SVC(kernel='rbf' , degree=1, gamma='auto', C=1)
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
accuracy = accuracy_score(y_pred , y_test)

# %%
print (f'Accuracy of the model is {accuracy}')
# Out:
# Accuracy of the model is 0.8967391304347826

# %%
#using cross validion 
from sklearn.model_selection import KFold, cross_val_score ,StratifiedKFold
#model = SVC(kernel='rbf' , degree=1, gamma='auto', C=1)

k_folds = KFold(n_splits = 10)
model = SVC(kernel='rbf' , degree=1, gamma='auto', C=1)


scores = cross_val_score(model, X_train, y_train, cv = k_folds)
print (f' score using cross validation method is {round(scores.mean()*100 , 2)}%')
# Out:
#  score using cross validation method is 90.37%

# %% [markdown]
# ##### 5.1.3 Logistic Regression

# %%
>>> from sklearn.linear_model import LogisticRegression
clf = LogisticRegression(random_state=0).fit(X_train, y_train)
print (f' score using train test method only is {clf.score(X_test, y_test)*100}%')
scores = cross_val_score(clf, X_train, y_train, cv = k_folds)
print('--------------------------------')
print(f'score using cross validaion is {scores.mean()*100}%')
# Out:
#  score using train test method only is 87.5%
# --------------------------------
# score using cross validaion is 90.36653091447612%

# %% [markdown]
# #### 5.2 Tree Models <a id=17></a>

# %% [markdown]
# ##### 5.2.1 Decision Tree

# %%
>>> from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier(random_state=0)
scores= cross_val_score(clf, X_train,y_train, cv=10)
print(f'score using cross validaion is {scores.mean()*100}%')
# Out:
# score using cross validaion is 86.15142539800074%

# %% [markdown]
# ##### 5.2.2 Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import make_classification
X, y = make_classification(n_samples=1000, n_features=4,
                       n_informative=2, n_redundant=0,
                        random_state=0, shuffle=False)
clf = RandomForestClassifier(max_depth=2, random_state=0)
clf.fit(X_train,y_train)
# Out:
# RandomForestClassifier(max_depth=2, random_state=0)

# %%
clf = RandomForestClassifier(n_estimators = 500, max_depth = 4,
                             max_features = 3, bootstrap = True, random_state = 18).fit(X_train, y_train)

# %%
from sklearn.metrics import confusion_matrix, f1_score, accuracy_score
y_pred= clf.predict(X_test)
score = accuracy_score(y_pred , y_test)
print(f'score using cross validaion is {score*100}%')
# Out:
# score using cross validaion is 86.41304347826086%

# %% [markdown]
# #### Conclusion on Algorithms and final outcome

# %% [markdown]
# ## svm and log regrssion perform better in this case
# ## cross validation perform better
